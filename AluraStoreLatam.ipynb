# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
totalPrecio1 = tienda["Precio"].sum()
print(f"Total de Precios: ${totalPrecio1:,}")

totalEnvio1 = tienda["Costo de envío"].sum()
print(f"Total de envios: ${totalEnvio1:,}")
# tienda.head()

totalTienda1 = totalPrecio1 + totalEnvio1
print(f"Total de ganancias en tienda 1: ${totalTienda1:,}")
# Out:
# Total de Precios: $1,150,880,400.0
# Total de envios: $61,377,900.0
# Total de ganancias en tienda 1: $1,212,258,300.0

# %%
totalPrecio2 = tienda2["Precio"].sum()
print(f"Total de precios: ${totalPrecio2:,}")

totalEnvio2 = tienda2["Costo de envío"].sum()
print(f"Total de envios: ${totalEnvio2:,}")
# tienda.head()

totalTienda2 = totalPrecio2 + totalEnvio2
print(f"Total de ganancias en tienda 2: ${totalTienda2:,}")
# Out:
# Total de precios: $1,116,343,500.0
# Total de envios: $59,485,100.0
# Total de ganancias en tienda 2: $1,175,828,600.0

# %%
totalPrecio3 = tienda3["Precio"].sum()
print(f"Total de precios: ${totalPrecio3:,}")

totalEnvio3 = tienda3["Costo de envío"].sum()
print(f"Total de envios: ${totalEnvio3:,}")
# tienda.head()

totalTienda3 = totalPrecio3 + totalEnvio3
print(f"Total de ganancias en tienda 3: ${totalTienda3:,}")
# Out:
# Total de precios: $1,098,019,600.0
# Total de envios: $58,516,600.0
# Total de ganancias en tienda 3: $1,156,536,200.0

# %%
totalPrecio4 = tienda4["Precio"].sum()
print(f"Total de precios: ${totalPrecio4:,}")

totalEnvio4 = tienda4["Costo de envío"].sum()
print(f"Total de envios: ${totalEnvio4:,}")
# tienda.head()

totalTienda4 = totalPrecio4 + totalEnvio4
print(f"Total de ganancias en tienda 4: ${totalTienda4:,}")
# Out:
# Total de precios: $1,038,375,700.0
# Total de envios: $55,317,400.0
# Total de ganancias en tienda 4: $1,093,693,100.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("Ventas por categoría en Tienda 1:")
ventas_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Producto'].count()
print(ventas_categoria_tienda1)
print("\n")
# Out:
# Ventas por categoría en Tienda 1:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Producto, dtype: int64

# %%
print("Ventas por categoría en Tienda 2:")
ventas_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Producto'].count()
print(ventas_categoria_tienda2)
print("\n")
# Out:
# Ventas por categoría en Tienda 2:
# Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# Name: Producto, dtype: int64

# %%
print("Ventas por categoría en Tienda 3:")
ventas_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Producto'].count()
print(ventas_categoria_tienda3)
print("\n")
# Out:
# Ventas por categoría en Tienda 3:
# Categoría del Producto
# Artículos para el hogar    177
# Deportes y diversión       277
# Electrodomésticos          278
# Electrónicos               451
# Instrumentos musicales     177
# Juguetes                   315
# Libros                     185
# Muebles                    499
# Name: Producto, dtype: int64

# %%
print("Ventas por categoría en Tienda 4:")
ventas_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Producto'].count()
print(ventas_categoria_tienda4)
# Out:
# Ventas por categoría en Tienda 4:
# Categoría del Producto
# Artículos para el hogar    201
# Deportes y diversión       277
# Electrodomésticos          254
# Electrónicos               451
# Instrumentos musicales     170
# Juguetes                   338
# Libros                     187
# Muebles                    480
# Name: Producto, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd
data = {
    'Calificacion': [4,1,1,4,5]
    }
df = pd.DataFrame(data)
promedio = df["Calificacion"].mean()

print ("El promedio de calidicaion es de la tienda 1 es:", promedio)

tienda.head()
# Out:
# El promedio de calidicaion es de la tienda 1 es: 3.0
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
import pandas as pd
data = {
    'Calificacion': [1,3,5,5,4]
    }
df = pd.DataFrame(data)
promedio = df["Calificacion"].mean()

print ("El promedio de calificaciond e la tienda 2 es:", promedio)

tienda2.head()
# Out:
# El promedio de calificaciond e la tienda 2 es: 3.6
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
import pandas as pd
data = {
    'Calificacion': [4,3,5,4,1]
    }
df = pd.DataFrame(data)
promedio = df["Calificacion"].mean()

print ("El promedio de calificaciond e la tienda 3 es:", promedio)

tienda3.head()
# Out:
# El promedio de calificaciond e la tienda 3 es: 3.4
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
import pandas as pd
data = {
    'Calificacion': [4,5,5,3,4]
    }
df = pd.DataFrame(data)
promedio = df["Calificacion"].mean()

print ("El promedio de calificaciond e la tienda 2 es:", promedio)

tienda4.head()
# Out:
# El promedio de calificaciond e la tienda 2 es: 4.2
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd
data =  {

"Producto": ["Electronicos","Muebles","juguetes","Electrodomesticos"],
 "Cantidad_vendida": [1,2,1,1,]

 }

df = pd.DataFrame(data)

ventas_por_producto = df.groupby("Producto")["Cantidad_vendida"].sum()

producto_mas_vendido = ventas_por_producto.idxmax()
producto_menos_vendido = ventas_por_producto.idxmin()

print("Producto más vendido:", producto_mas_vendido)
print("Producto menos vendido:", producto_menos_vendido)
# Out:
# Producto más vendido: Muebles
# Producto menos vendido: Electrodomesticos

# %%
import pandas as pd
data =  {

"Producto": ["Muebles","Instrumentos musicales"],
 "Cantidad_vendida": [2,1]

 }

df = pd.DataFrame(data)

ventas_por_producto = df.groupby("Producto")["Cantidad_vendida"].sum()

producto_mas_vendido = ventas_por_producto.idxmax()
producto_menos_vendido = ventas_por_producto.idxmin()

print("Producto más vendido:", producto_mas_vendido)
print("Producto menos vendido:", producto_menos_vendido)
# Out:
# Producto más vendido: Muebles
# Producto menos vendido: Instrumentos musicales

# %%
import pandas as pd
data =  {

"Producto": ["Electrodomésticos","Muebles","Instrumentos musicales","Deportes y diversión"],
 "Cantidad_vendida": [1,2,1,1]

 }

df = pd.DataFrame(data)

ventas_por_producto = df.groupby("Producto")["Cantidad_vendida"].sum()

producto_mas_vendido = ventas_por_producto.idxmax()
producto_menos_vendido = ventas_por_producto.idxmin()

print("Producto más vendido:", producto_mas_vendido)
print("Producto menos vendido:", producto_menos_vendido)
# Out:
# Producto más vendido: Muebles
# Producto menos vendido: Deportes y diversión

# %%
import pandas as pd
data =  {

"Producto": ["Electrodomésticos","Muebles","Deportes y diversión","Libros","Electrónicos"],
 "Cantidad_vendida": [1,1,1,1,1]

 }

df = pd.DataFrame(data)

ventas_por_producto = df.groupby("Producto")["Cantidad_vendida"].sum()

producto_mas_vendido = ventas_por_producto.idxmax()
producto_menos_vendido = ventas_por_producto.idxmin()

print("Producto más vendido:", producto_mas_vendido)
print("Producto menos vendido:", producto_menos_vendido)
# Out:
# Producto más vendido: Deportes y diversión
# Producto menos vendido: Deportes y diversión

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
data = {
    'Envio': [6900.0,8400.0,15900.0,41000.0,20200.0]
    }
df = pd.DataFrame(data)
promedio = df["Envio"].mean()

print ("El promedio de Envio e la tienda 1 es:", promedio)

tienda.head()
# Out:
# El promedio de Envio e la tienda 1 es: 18480.0
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
import pandas as pd
data = {
    'Envio': [15300.0,2300.0,23800.0,46400.0,19400.0]
    }
df = pd.DataFrame(data)
promedio = df["Envio"].mean()

print ("El promedio de Envio e la tienda 2 es:", promedio)

tienda2.head()
# Out:
# El promedio de Envio e la tienda 2 es: 21440.0
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
import pandas as pd
data = {
    'Envio': [66600.0,13600.0,17400.0,3300.0,25900.0]
    }
df = pd.DataFrame(data)
promedio = df["Envio"].mean()

print ("El promedio de Envio e la tienda 3 es:", promedio)

tienda3.head()
# Out:
# El promedio de Envio e la tienda 3 es: 25360.0
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
import pandas as pd
data = {
    'Envio': [56000.0,25400.0,0.0,1300.0,5600.0]
    }
df = pd.DataFrame(data)
promedio = df["Envio"].mean()

print ("El promedio de Envio e la tienda 4 es:", promedio)

tienda4.head()
# Out:
# El promedio de Envio e la tienda 4 es: 17660.0
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# ...
